# %% [markdown]
# <a href="https://colab.research.google.com/github/Srabanisarkar/Iris/blob/main/IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
iris=pd.read_csv("/content/drive/MyDrive/DATASET/IRIS.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print(iris.tail(8))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris.shape
# Out:
# (150, 5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(iris[4:8])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa

# %%
iris.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris['sepal_length'].hist()
# Out:
# <Axes: >

# %%
iris['sepal_width'].hist()
# Out:
# <Axes: >

# %%
iris['petal_length'].hist()
# Out:
# <Axes: >

# %%
iris['petal_width'].hist()
# Out:
# <Axes: >

# %%
colors =['red','orange','blue']
Species = ['Iris-setosa','Iris-virginica','Iris-versicolor']

# %%
for i in range(3):
   x = iris[iris['species']==Species[i]]
   plt.scatter(x['sepal_length'],x['sepal_width'],c=colors[i],label=Species[i])
   plt.xlabel('sepal_length')
   plt.ylabel('sepal_width')
   plt.legend()

# %%
iris.corr()
# Out:
# <ipython-input-166-156dd03bc859>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
corr = iris.corr()
fig,ax=plt.subplots(figsize=(10,10))
sns.heatmap(corr,annot=True,ax=ax)
# Out:
# <ipython-input-167-215ec7b868b4>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
df=px.data.iris()
fig=px.scatter_3d(df,x='sepal_length',y='sepal_width',z='petal_width' ,color='species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5e674015-bef4-4524-ad26-7e626f82539e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e674015-bef4-4524-ad26-7e626f82539e")) {                    Plotly.newPlot(                        "5e674015-bef4-4524-ad26-7e626f82539e",                        [{"hovertemplate":"species=setosa<br>sepal_length=%{x}<br>sepal_width=%{y}<br>petal_width=%{z}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":
marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"virginica","scene":"scene","showlegend":true,"x":[6.3,5.8,7.1,6.3,6.5,7.6,4.9,7.3,6.7,7.2,6.5,6.4,6.8,5.7,5.8,6.4,6.5,7.7,7.7,6.0,6.9,5.6,7.7,6.3,6.7,7.2,6.2,6.1,6.4,7.2,7.4,7.9,6.4,6.3,6.1,7.7,6.3,6.4,6.0,6.9,6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],"y":[3.3,2.7,3.0,2.9,3.0,3.0,2.5,2.9,2.5,3.6,3.2,2.7,3.0,2.5,2.8,3.2,3.0,3.8,2.6,2.2,3.2,2.8,2.8,2.7,3.3,3.2,2.8,3.0,2.8,3.0,2.8,3.8,2.8,2.8,2.6,3.0,3.4,3.1,3.0,3.1,3.1,3.1,2.7,3.2,3.3,3.0,2.5,3.0,3.4,3.0],"z":[2.5,1.9,2.1,1.8,2.2,2.1,1.7,1.8,1.8,2.5,2.0,1.9,2.1,2.0,2.4,2.3,1.8,2.2,2.3,1.5,2.3,2.0,2.0,1.8,2.1,1.8,1.8,1.8,2.1,1.6,1.9,2.0,2.2,1.5,1.4,2.3,2.4,1.8,1.8,2.1,2.4,2.3,1.9,2.3,2.5,2.3,1.9,2.0,2.3,1.8],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.mean()
# Out:
# <ipython-input-171-7eed97565d6e>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
iris.loc[3]
# Out:
# sepal_length            4.6
# sepal_width             3.1
# petal_length            1.5
# petal_width             0.2
# species         Iris-setosa
# Name: 3, dtype: object

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.iloc[3]
# Out:
# sepal_length            4.6
# sepal_width             3.1
# petal_length            1.5
# petal_width             0.2
# species         Iris-setosa
# Name: 3, dtype: object

# %%
iris.iloc[2:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.loc[2:3]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa

# %%
iris['species'].value_counts()[0:3]
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
iris.groupby(['species']).count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %%
sns.pairplot(iris,hue='species',height=2)

# %%
iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa

# %%
iris.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
iris.median()
# Out:
# <ipython-input-182-7f9b4600b8ea>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
# X=iris.drop('species',axis=1)
# Y=iris['species']
# Y.shape

# %%
# with the following features we can find highly correlated features
# def correlation(dataset,threshold):
#     col_corr=set()
#     corr=dataset.corr()
#     for i in range(len(corr.columns)):
#         for j in range(i):
#             if abs(corr.iloc[i,j])>threshold:
#                 colname=corr.columns[i]
#                 col_corr.add(colname)
#     return col_corr

# %%
# corr_features=correlation(X,0.8)
# print(corr_features)

# %%
# X_new=X.drop(corr_features,axis=1)
# X_new

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
iris.species=le.fit_transform(iris.species)
X=iris.drop(['species'],axis=1)
y=iris['species']
print(X)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=2)

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predicted_lr=lr.predict(X_test)

# %%
import sklearn.metrics as metrics
cm_lr=metrics.confusion_matrix(y_test,predicted_lr)
cmd=ConfusionMatrixDisplay(cm_lr,display_labels=['0','1','2'])
cmd.plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.91      0.95        11
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
accuracy_lr=metrics.accuracy_score(y_test,predicted_lr)
accuracy_lr
# Out:
# 0.9736842105263158

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

naive=GaussianNB()
naive.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
predicted_naive=naive.predict(X_test)
print(predicted_naive)
# Out:
# [0 0 2 0 0 2 0 2 2 0 0 0 0 0 1 1 0 1 2 1 2 1 2 1 1 0 0 2 0 2 2 0 1 2 1 0 2
#  1]

# %%
import sklearn.metrics as metrics
cm_naive=metrics.confusion_matrix(y_test,predicted_naive)
print(cm_naive)
# Out:
# [[16  0  0]
#  [ 0 10  1]
#  [ 0  0 11]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cmd=ConfusionMatrixDisplay(cm_naive,display_labels=['0', '1', '2'])
cmd.plot()

# %%
accuracy_score=metrics.accuracy_score(y_test,predicted_naive)
print(accuracy_score)
# Out:
# 0.9736842105263158

# %%
from sklearn.metrics import roc_curve
naive_probs=naive.predict_proba(X_test)
fpr={}
tpr={}
thresh={}
n_class=3
for i in range(n_class):
    fpr[i],tpr[i],thresh[i]=roc_curve(y_test,naive_probs[:,i],pos_label=i)
plt.plot(fpr[0],tpr[0], linestyle='dotted',color='green',label='Class 0 Vs Rest')
plt.plot(fpr[1],tpr[1], linestyle='dotted',color='red',label='Class 1 Vs Rest')
plt.plot(fpr[2],tpr[2], linestyle='dotted',color='orange',label='Class 2 Vs Rest')
plt.title('Multiclass Roc Curve')
# Out:
# Text(0.5, 1.0, 'Multiclass Roc Curve')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted_naive))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.91      0.95        11
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %% [markdown]
# K Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predicted_knn=knn.predict(X_test)

# %%
cm_knn=metrics.confusion_matrix(y_test,predicted_knn)
cmd=ConfusionMatrixDisplay(cm_knn,display_labels=['0','1','2'])
cmd.plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
accuracy_knn=metrics.accuracy_score(y_test,predicted_knn)
accuracy_knn
# Out:
# 1.0

# %%
knn_probs=knn.predict_proba(X_test)
fpr={}
tpr={}
thresh={}
n_class=3
for i in range(n_class):
    fpr[i],tpr[i],thresh[i]=roc_curve(y_test,knn_probs[:,i],pos_label=i)
plt.plot(fpr[0],tpr[0], linestyle='dotted',color='red',label='Class 0 vs rest')
plt.plot(fpr[1],tpr[1], linestyle='dotted',color='green',label='Class 1 vs rest')
plt.plot(fpr[2],tpr[2], linestyle='dotted',color='orange',label='Class 2 vs rest')

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_dtree=dtree.predict(X_test)
predicted_dtree
# Out:
# array([0, 0, 2, 0, 0, 1, 0, 2, 2, 0, 0, 0, 0, 0, 1, 1, 0, 1, 2, 1, 2, 1,
#        2, 1, 1, 0, 0, 2, 0, 2, 2, 0, 1, 2, 1, 0, 2, 1])

# %%
cm_dtree=metrics.confusion_matrix(y_test,predicted_dtree)
cmd=ConfusionMatrixDisplay(cm_dtree,display_labels=['0','1','2'])
cmd.plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.91      0.91      0.91        11
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.95        38
#    macro avg       0.94      0.94      0.94        38
# weighted avg       0.95      0.95      0.95        38

# %%
dtree_probs=dtree.predict_proba(X_test)
fpr={}
tpr={}
thresh={}
n_class=3
for i in range(n_class):
    fpr[i],tpr[i],thresh[i]=roc_curve(y_test,dtree_probs[:,i],pos_label=i)
plt.plot(fpr[0],tpr[0],linestyle='dotted',color='red',label='Class 0 vs Rest')
plt.plot(fpr[1],tpr[1],linestyle='dotted',color='orange',label='Class 1 vs Rest')
plt.title('MultiClass ROC Curve')
# Out:
# Text(0.5, 1.0, 'MultiClass ROC Curve')

# %%
accuracy_dtree=metrics.accuracy_score(y_test,predicted_dtree)
accuracy_dtree
# Out:
# 0.9473684210526315

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rforest=RandomForestClassifier()
rforest.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predicted_rforest=rforest.predict(X_test)

# %%
cm_rforest=metrics.confusion_matrix(y_test,predicted_rforest)
cmd=ConfusionMatrixDisplay(cm_rforest,display_labels=['0','1','2'])
cmd.plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted_rforest))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.91      0.95        11
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
accuracy_rforest=metrics.accuracy_score(y_test,predicted_rforest)
accuracy_rforest
# Out:
# 0.9736842105263158

# %%
rforest_probs=rforest.predict_proba(X_test)
fpr={}
tpr={}
thresh={}
n_class=3
for i in range(n_class):
    fpr[i],tpr[i],thresh[i]=roc_curve(y_test,rforest_probs[:,i],pos_label=i)
plt.plot(fpr[0],tpr[0],linestyle='dashed',color='red',label='Class 0 Vs Rest')
plt.plot(fpr[1],tpr[1],linestyle='dashed',color='green',label='Class 1 Vs Rest')
plt.plot(fpr[2],tpr[2],linestyle='dashed',color='orange',label='Class 2 Vs Rest')
plt.title('Multiclass ROC Curve')
# Out:
# Text(0.5, 1.0, 'Multiclass ROC Curve')

# %%
accuracy_rforest=metrics.accuracy_score(y_test,predicted_rforest)
accuracy_rforest
# Out:
# 0.9736842105263158
